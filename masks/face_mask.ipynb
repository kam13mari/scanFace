# %%
# !pip install Pillow

# %%
import os
from pathlib import Path
from PIL import Image 
from ultralytics import YOLO
import pandas as pd
import csv
import shutil
from pathlib import Path
import torch
import cv2

# %%
CWD = Path.cwd()
base_dir = CWD.joinpath('data') 

no_mask_folder = base_dir.joinpath('without_mask')
with_mask_folder = base_dir.joinpath('with_mask') 
output_labels_dir = base_dir / 'labels'

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt") 

model.train(data='mask.yaml', model='yolov11n.pt', epochs=30, device='cpu', project=CWD.joinpath('models'))
